# %%
from nltk import PCFG,InsideChartParser

# %%
grammar=PCFG.fromstring("""
S -> NP VP [1.0] 
NP -> NP PP [0.4] | 'he' [0.1] | 'dessert' [0.3] | 'lunch' [0.1] | 'saw' [0.1] 
PP -> Pre NP [1.0] 
VP -> Verb NP [0.3] | VP PP [0.7] 
Pre -> 'with' [0.6] | 'in' [0.4] 
Verb -> 'ate' [0.7] | 'saw' [0.3]
""")
parser=InsideChartParser(grammar)
tokens="he saw lunch with dessert".split()
for tree in parser.parser(tokens):
    tree.pretty_print()
    print("Proba:",tree.prob())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 11
#       9 parser=InsideChartParser(grammar)
#      10 tokens="he saw lunch with dessert".split()
# ---> 11 for tree in parser.parser(tokens):
#      12     tree.pretty_print()
#      13     print("Proba:",tree.prob())
#
# AttributeError: 'InsideChartParser' object has no attribute 'parser'
